# %%
# !conda install -c conda-forge wikipedia --yes
#!pip install wikipedia
import pandas as pd
import wikipedia as wp
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - wikipedia
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     wikipedia-1.4.0            |           py35_0          20 KB  conda-forge
#
# The following NEW packages will be INSTALLED:
#
#     wikipedia: 1.4.0-py35_0 conda-forge
#
#
# Downloading and Extracting Packages
# wikipedia-1.4.0      | 20 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# Data from wikipage

# %%
# Get the table from wiki page
html = wp.page("List of postal codes of Canada: M").html().encode("UTF-8")
df = pd.read_html(html, header = 0)[0]

# Drope the rows with Borough of "Not assigned"
df_assigned = df[df.Borough != 'Not assigned']
df_assigned.reset_index(drop = True, inplace = True)

# Merge rows with the same Postcode
df_assigned = df_assigned.groupby(['Postcode', 'Borough'], as_index=False).agg(lambda x: ', '.join(set(x)))

# Set 'Not assigned' Neigbourhood to be equal to Borough
na_nb_idx =df_assigned['Neighbourhood'] == 'Not assigned'
df_assigned.loc[na_nb_idx, 'Neighbourhood'] = df_assigned[na_nb_idx].Borough
df_assigned[df_assigned['Postcode'] == 'M7A']
# Out:
#    Postcode       Borough Neighbourhood
# 85      M7A  Queen's Park  Queen's Park

# %%
df_assigned.shape
# Out:
# (103, 3)

# %% [markdown]
# Add latitude and longitude of each neighborhood

# %%
# !wget -O GeoCord.csv http://cocl.us/Geospatial_data/
# Out:
# --2019-05-15 15:37:58--  http://cocl.us/Geospatial_data/
# Resolving cocl.us (cocl.us)... 169.48.113.201
# Connecting to cocl.us (cocl.us)|169.48.113.201|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data/ [following]
# --2019-05-15 15:37:58--  https://cocl.us/Geospatial_data/
# Connecting to cocl.us (cocl.us)|169.48.113.201|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-05-15 15:38:01--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.27.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.27.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-05-15 15:38:02--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-05-15 15:38:02--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.27.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.27.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!oQ4FZdzknQK2dh2reQfJaEtDTxA1rd6nutBmQRU9Y4-6iFARlgZeiiBlbXr9LNLveJDRQyz2ywiYnW1gfYldVcgUiI2CG2lDmg2vWG_HpvgkgeZ3BpK65vEbK9FEfUFX4IzlzPNHaa2-OKqsy7u7kiBBZcrxyUBTt_arE6C8LFwQ89TXpEYGPVwXejbe92qpMMaIJLQqLLWi0zI7E33jwiRsiL4Dfk-Kv3dx6DQ0p45QUOtyO6zv3_EF-ewpfWRBr_1RLDFpfR8IwnkIcuaRypegLZha71TaJCIKFTXJ58Ssi1F2zu9-XdhEbdlwaghjSy2iljRvAX7PE8ecwrxt1cmwvJkGJjDglJDYwgMvXPotvqcbKOgGGb2-BVzcX8vF7_3y47x1pLuv1EdUF1nSS6VrIjHWSspxgkfnFpZ6KyscAnOi5Z-8u7GYQByaHQK19ni7wpZI_SrTjwrRYj-YE6_dz2k-jlx2IMCc5ZjP1rqB5wt0BlsmGTnjcHvPu_zO2dZCsneeKCXJIZ6ErfyD7RNHYe-kMi_3BGrc0jw6ABwN47i4p552x5Bvq7e9TCo5ihZjE4g4BzQtwv5Qhx1OAXUdOnbfXAF3wtdN0dSdSqvUVw26mLNxAAMafaA-zWCu2mLviGaGbDbHI3pgPkHZrIM0swmQUFrZnS0Mbz1pBSUg3r7y3oT6aiOg8lA1_YfghE09nX9caTjaHym9UFfJG1jOkA2Nqi90cSK0J3Nu8iyHPNvxLd07tM_Pn5E848-JgLDQpf46euVh4Bw_VubncYh1XUaJ-Jv4RsS5SmPzhweMA0t
6FZP2guge7y55OfhhwpBxw-EXTLrR7eSE2UjvWN1O0IiKdyawszAvhWhnvt9KNXsVr5itrtDDxWdKHNIW4PepnSMxYBG9LBQe3SK5WE0Crs5CaEJQ8JcSHpHgFW_gQW0VvSTwEEuQ8nz2L-rCuIlur7irzB-Axm9Of5tVqWEDuKj8hWN_uOrE5T7JQRyDb10H31QETwRdON3oQpJWW0YjreJ6tYuQ67oPMPGQEmsGN3qtyXjhIipI2IGIV4krfObu3Odz0sIw-T_Xk9N2a2djI1JOkEk10s-O76wudk-jElLvCpg1GN73K-O1d1EjfBl-njobHaXl_Q4nvQOx1LrI9Fc9FrVwbP8eJz0Z-W_rz9K1h8_CkCxwaCY66Q0SBludJ7tqKG3DOtBJUWIX32nxV5j9RPXmOrQnL2pQbGSWQI8aT_Cg6fgLBjMGJcvIz6xJEsXPZy0Ssi8uMaRm2ZMWcSM16XRHHV14RXcXoteF4-3PkPLDbIyYCwdlL-qcmLs./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.24.200, 107.152.25.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.24.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘GeoCord.csv’
#
# 100%[======================================>] 2,891       --.-K/s   in 0s
#
# 2019-05-15 15:38:03 (319 MB/s) - ‘GeoCord.csv’ saved [2891/2891]

# %%
df_cord = pd.read_csv('GeoCord.csv') # Read the csv data
df_cord.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
import numpy as np

# %%
# Create Latitude and Longitude columns in df_assigned
df_assigned['Latitude'] = np.nan
df_assigned['Longitude'] = np.nan

# For each postcode in df_assigned, find corresponding coordinates in df_cord and assign it to df_assigned
for idx in df_assigned.index:
    cord_idx = df_cord['Postal Code'] == df_assigned.loc[idx, 'Postcode']
    df_assigned.at[idx, 'Latitude'] = df_cord.loc[cord_idx, 'Latitude'].values
    df_assigned.at[idx, 'Longitude'] = df_cord.loc[cord_idx, 'Longitude'].values

# Display the results
df_assigned
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                       Rouge, Malvern  43.806686 -79.194353
# 1               Port Union, Highland Creek, Rouge Hill  43.784535 -79.160497
# 2                    West Hill, Morningside, Guildwood  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6          Ionview, Kennedy Park, East Birchmount Park  43.727929 -79.262029
# 7                      Golden Mile, Oakridge, Clairlea  43.711112 -79.284577
# 8      Scarborough Village West, Cliffcrest, Cliffside  43.716316 -79.239476
# 9                          Cliffside West, Birch Cliff  43.692657 -79.264848
# 10   Dorset Park, Wexford Heights, Scarborough Town...  43.757410 -79.273304
# 11                                   Maryvale, Wexford  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13             Tam O'Shanter, Sullivan, Clarks Corners  43.781638 -79.304302
# 14   Milliken, Steeles East, Agincourt North, L'Amo...  43.815252 -79.284577
# 15                                     L'Amoreaux West  43.799525 -79.318389
# 16                                         Upper Rouge  43.836125 -79.205636
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                        Henry Farm, Oriole, Fairview  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                            York Mills, Silver Hills  43.757490 -79.374714
# 21                             Willowdale, Newtonbrook  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                    Don Mills South, Flemingdon Park  43.725900 -79.340923
# 28     Wilson Heights, Bathurst Manor, Downsview North  43.754328 -79.442259
# 29                     Northwood Park, York University  43.767980 -79.487262
# ..                                                 ...        ...        ...
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                        Dovercourt Village, Dufferin  43.669005 -79.442259
# 77                            Trinity, Little Portugal  43.647927 -79.419750
# 78        Exhibition Place, Brockton, Parkdale Village  43.636847 -79.428191
# 79                  North Park, Downsview, Upwood Park  43.713756 -79.490074
# 80      Del Ray, Silverthorn, Keelesdale, Mount Dennis  43.691116 -79.476013
# 81                       The Junction North, Runnymede  43.673185 -79.487262
# 82                       High Park, The Junction South  43.661608 -79.464763
# 83                              Roncesvalles, Parkdale  43.648960 -79.456325
# 84                                  Swansea, Runnymede  43.651571 -79.484450
# 85                                        Queen's Park  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88        New Toronto, Mimico South, Humber Bay Shores  43.605647 -79.501321
# 89                              Alderwood, Long Branch  43.602414 -79.543484
# 90       Old Mill North, The Kingsway, Montgomery Road  43.653654 -79.506944
# 91   Old Mill South, Mimico NE, Royal York South Ea...  43.636258 -79.498509
# 92   Mimico NW, The Queensway West, Kingsway Park S...  43.628841 -79.520999
# 93                                    Islington Avenue  43.667856 -79.532242
# 94   Cloverdale, Princess Gardens, Islington, West ...  43.650943 -79.554724
# 95   Markland Wood, Bloordale Gardens, Old Burnhamt...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                    Humberlea, Emery  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 101  Albion Gardens, South Steeles, Thistletown, Si...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %%
from geopy.geocoders import Nominatim

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-2.2.2               |           py35_1         462 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         560 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# altair-2.2.2         | 462 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# Msrking Nighboorhood in MAP

# %%
address = 'Toronto, Canada'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighbourhood in zip(df_assigned['Latitude'], df_assigned['Longitude'], df_assigned['Borough'], df_assigned['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
